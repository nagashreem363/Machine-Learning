# %% [markdown]
# <a href="https://colab.research.google.com/github/nagashreem363/Machine-Learning/blob/main/Complete_case_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv('/content/sales.csv')
data
# Out:
#       product_id store_id        date  sales  revenue  stock  price  \
# 0          P0001    S0002  2017-01-02    0.0     0.00    8.0   6.25
# 1          P0001    S0012  2017-01-02    1.0     5.30    0.0   6.25
# 2          P0001    S0013  2017-01-02    2.0    10.59    0.0   6.25
# 3          P0001    S0023  2017-01-02    0.0     0.00    6.0   6.25
# 4          P0001    S0025  2017-01-02    0.0     0.00    1.0   6.25
# ...          ...      ...         ...    ...      ...    ...    ...
# 95235      P0197    S0043  2017-01-09    0.0     0.00   32.0   3.50
# 95236      P0197    S0051  2017-01-09    0.0     0.00    8.0   3.50
# 95237      P0197    S0055  2017-01-09    1.0     3.24   12.0   3.50
# 95238      P0197    S0062  2017-01-09    0.0     0.00    9.0   3.50
# 95239      P0197    S0066  2017-01-09    2.0     6.00    NaN    NaN
#
#       promo_type_1 promo_bin_1 promo_type_2  promo_bin_2  promo_discount_2  \
# ...

# %%
data.isnull().mean()*100
# Out:
# product_id                 0.00000
# store_id                   0.00000
# date                       0.00000
# sales                      0.00000
# revenue                    0.00000
# stock                      0.00105
# price                      1.48362
# promo_type_1               0.00105
# promo_bin_1               88.98047
# promo_type_2               0.00105
# promo_bin_2              100.00000
# promo_discount_2         100.00000
# promo_discount_type_2    100.00000
# dtype: float64

# %%
data.dropna(subset=['price'],inplace=True)
data
# Out:
#       product_id store_id        date  sales  revenue  stock  price  \
# 0          P0001    S0002  2017-01-02    0.0     0.00    8.0   6.25
# 1          P0001    S0012  2017-01-02    1.0     5.30    0.0   6.25
# 2          P0001    S0013  2017-01-02    2.0    10.59    0.0   6.25
# 3          P0001    S0023  2017-01-02    0.0     0.00    6.0   6.25
# 4          P0001    S0025  2017-01-02    0.0     0.00    1.0   6.25
# ...          ...      ...         ...    ...      ...    ...    ...
# 95234      P0197    S0040  2017-01-09    0.0     0.00    1.0   3.50
# 95235      P0197    S0043  2017-01-09    0.0     0.00   32.0   3.50
# 95236      P0197    S0051  2017-01-09    0.0     0.00    8.0   3.50
# 95237      P0197    S0055  2017-01-09    1.0     3.24   12.0   3.50
# 95238      P0197    S0062  2017-01-09    0.0     0.00    9.0   3.50
#
#       promo_type_1 promo_bin_1 promo_type_2  promo_bin_2  promo_discount_2  \
# ...
