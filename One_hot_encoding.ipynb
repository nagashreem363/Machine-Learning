# %% [markdown]
# <a href="https://colab.research.google.com/github/nagashreem363/Machine-Learning/blob/main/One_hot_encoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('/content/diabetes_prediction_dataset.csv')
data.shape
# Out:
# (100000, 9)

# %%
data.smoking_history.value_counts()
# Out:
# smoking_history
# No Info        35816
# never          35095
# former          9352
# current         9286
# not current     6447
# ever            4004
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test=train_test_split(data,test_size=0.2)

# %%
x_train
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 75206  Female  46.0             0              0         current  37.16
# 40135    Male  37.0             0              0           never  33.21
# 64104  Female  64.0             1              0            ever  27.80
# 47511    Male  41.0             0              0     not current  27.32
# 6663   Female  26.0             0              0         No Info  19.80
# ...       ...   ...           ...            ...             ...    ...
# 27740  Female  41.0             0              0         No Info  27.32
# 87950  Female  38.0             0              0         No Info  48.79
# 40172  Female  36.0             0              0         current  32.41
# 73915    Male  37.0             0              0         No Info  27.32
# 13500    Male  80.0             0              0         No Info  27.32
#
#        HbA1c_level  blood_glucose_level  diabetes
# 75206          6.6                  159         0
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
ohe=OneHotEncoder()
new=ohe.fit_transform(x_train[['gender','smoking_history']]).toarray()
new.shape
# Out:
# (80000, 9)

# %%
x_train[['age','hypertension','heart_disease','bmi']].values.shape
# Out:
# (80000, 4)

# %%
a=np.hstack((x_train[['age','hypertension','heart_disease','bmi']].values,new))
