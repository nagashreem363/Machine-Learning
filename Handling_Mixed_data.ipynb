# %% [markdown]
# <a href="https://colab.research.google.com/github/nagashreem363/Machine-Learning/blob/main/Handling_Mixed_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('/content/titanic.csv')
data.dropna(inplace=True)
data
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 14           906         1       1
# 24           916         1       1
# 26           918         1       1
# 28           920         0       1
# ..           ...       ...     ...
# 404         1296         0       1
# 405         1297         0       2
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 26                        Ostby, Miss. Helene Ragnhild  female  22.0      0
# 28                             Brady, Mr. John Bertram    male  41.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data['Cabin'].unique()
# Out:
# array(['B45', 'E31', 'B57 B59 B63 B66', 'B36', 'A21', 'C78', 'D19', 'A9',
#        'D15', 'C31', 'C23 C25 C27', 'F G63', 'B61', 'C53', 'D43', 'C130',
#        'C132', 'C101', 'C55 C57', 'B71', 'C46', 'C116', 'F', 'A29', 'G6',
#        'C6', 'C28', 'C51', 'C54', 'C97', 'D22', 'B10', 'F4', 'E45', 'E52',
#        'D30', 'B58 B60', 'E34', 'C62 C64', 'A11', 'B11', 'C80', 'F33',
#        'C85', 'D37', 'C86', 'D21', 'C89', 'A34', 'B26', 'C22 C26', 'B69',
#        'C32', 'B78', 'F E57', 'F2', 'A18', 'C106', 'B51 B53 B55',
#        'D10 D12', 'E60', 'E50', 'E39 E41', 'B52 B54 B56', 'C39', 'B24',
#        'D28', 'B41', 'C7', 'D40', 'D38', 'C105'], dtype=object)

# %%
data['cabin_num']=data['Cabin'].str.extract('(\d+)')
data['cabin_cat']=data['Cabin'].str[0]
data
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 14           906         1       1
# 24           916         1       1
# 26           918         1       1
# 28           920         0       1
# ..           ...       ...     ...
# 404         1296         0       1
# 405         1297         0       2
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 26                        Ostby, Miss. Helene Ragnhild  female  22.0      0
# 28                             Brady, Mr. John Bertram    male  41.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data['cabin_cat'].value_counts()
# Out:
# cabin_cat
# C    35
# B    18
# D    11
# E     8
# A     7
# F     7
# G     1
# Name: count, dtype: int64
